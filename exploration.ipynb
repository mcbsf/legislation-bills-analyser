# %%
import pandas as pd
from analysers.legislator_analyser import LegislatorAnalyser

# %%
bills_df = pd.read_csv('input/bills.csv')
legislators_df = pd.read_csv('input/legislators.csv')
votes_df = pd.read_csv('input/votes.csv')
vote_results_df = pd.read_csv('input/vote_results.csv')

# %%
vote_results_df.head()
# Out:
#          id  legislator_id  vote_id  vote_type
# 0  92516784         400440  3321166          2
# 1  92516770          17941  3321166          2
# 2  92516768         400414  3321166          2
# 3  92516753         400380  3321166          2
# 4  92516734         412393  3321166          2

# %%
legislator_analyser = LegislatorAnalyser(legislators_df, vote_results_df)

# %%
legislator_analyser.parse_legislators_id_column_to_match_vote_results()
legislator_analyser.split_votes_count_by_vote_type()
legislator_analyser.get_legislators_name()
legislator_analyser.write_csv()

# %%
from analysers.bills_analyser import BillsAnalyser


bills_analyser = BillsAnalyser(votes_df, bills_df, vote_results_df, legislators_df)

# %%
bills_analyser.parse_columns_to_match_pandas_merge()

# %%
bills_analyser.get_votes_by_bill()

# %%
bills_analyser.bills_df
# Out:
#     bill_id                                              title  legislator_id
# 0   2952375                   H.R. 5376: Build Back Better Act         412211  \
# 1   2952375                   H.R. 5376: Build Back Better Act         412211
# 2   2952375                   H.R. 5376: Build Back Better Act         412211
# 3   2952375                   H.R. 5376: Build Back Better Act         412211
# 4   2952375                   H.R. 5376: Build Back Better Act         412211
# 5   2952375                   H.R. 5376: Build Back Better Act         412211
# 6   2952375                   H.R. 5376: Build Back Better Act         412211
# 7   2952375                   H.R. 5376: Build Back Better Act         412211
# 8   2952375                   H.R. 5376: Build Back Better Act         412211
# 9   2952375                   H.R. 5376: Build Back Better Act         412211
# 10  2952375                   H.R. 5376: Build Back Better Act         412211
# 11  2952375                   H.R. 5376: Build Back Better Act         412211
# 12  2952375                   H.R. 5376: Build Back Better Act         412211
# 13  2952375                   H.R. 5376: Build Back Better Act         412211
# 14  2952375                   H.R. 5376: Build Back Better Act         412211
# 15  2952375                   H.R. 5376: Build Back Better Act         412211
# 16  2952375                   H.R. 5376: Build Back Better Act         412211
# 17  2952375                   H.R. 5376: Build Back Better Act         412211
# 18  2952375                   H.R. 5376: Build Back Better Act         412211
# 19  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 20  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 21  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 22  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 23  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 24  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 25  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 26  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 27  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 28  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 29  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 30  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 31  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 32  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 33  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 34  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 35  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 36  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
# 37  2900994  H.R. 3684: Infrastructure Investment and Jobs Act         400100
#
#     vote_id        id  vote_type                        name
# 0   3321166  92516784          2  Rep. John Yarmuth (D-KY-3)
# 1   3321166  92516770          2  Rep. John Yarmuth (D-KY-3)
# 2   3321166  92516768          2  Rep. John Yarmuth (D-KY-3)
# 3   3321166  92516753          2  Rep. John Yarmuth (D-KY-3)
# 4   3321166  92516734          2  Rep. John Yarmuth (D-KY-3)
# 5   3321166  92516711          2  Rep. John Yarmuth (D-KY-3)
# 6   3321166  92516702          2  Rep. John Yarmuth (D-KY-3)
# 7   3321166  92516688          2  Rep. John Yarmuth (D-KY-3)
# 8   3321166  92516683          2  Rep. John Yarmuth (D-KY-3)
# 9   3321166  92516647          2  Rep. John Yarmuth (D-KY-3)
# 10  3321166  92516640          2  Rep. John Yarmuth (D-KY-3)
# 11  3321166  92516632          2  Rep. John Yarmuth (D-KY-3)
# 12  3321166  92516579          2  Rep. John Yarmuth (D-KY-3)
# 13  3321166  92516553          1  Rep. John Yarmuth (D-KY-3)
# 14  3321166  92516513          1  Rep. John Yarmuth (D-KY-3)
# 15  3321166  92516500          1  Rep. John Yarmuth (D-KY-3)
# 16  3321166  92516499          1  Rep. John Yarmuth (D-KY-3)
# 17  3321166  92516373          1  Rep. John Yarmuth (D-KY-3)
# 18  3321166  92516368          1  Rep. John Yarmuth (D-KY-3)
# 19  3314452  92280168          2                     Unknown
# 20  3314452  92280136          2                     Unknown
# 21  3314452  92280128          2                     Unknown
# 22  3314452  92280127          2                     Unknown
# 23  3314452  92280007          2                     Unknown
# 24  3314452  92279998          2                     Unknown
# 25  3314452  92279979          1                     Unknown
# 26  3314452  92279965          1                     Unknown
# 27  3314452  92279964          1                     Unknown
# 28  3314452  92279943          1                     Unknown
# 29  3314452  92279920          1                     Unknown
# 30  3314452  92279888          1                     Unknown
# 31  3314452  92279879          1                     Unknown
# 32  3314452  92279858          1                     Unknown
# 33  3314452  92279850          1                     Unknown
# 34  3314452  92279828          1                     Unknown
# 35  3314452  92279823          1                     Unknown
# 36  3314452  92279817          1                     Unknown
# 37  3314452  92279758          1                     Unknown

# %%
bills_analyser.split_votes_count_by_vote_type()

# %%
bills_analyser.bills_df
# Out:
#    bill_id                                              title
# 0  2900994  H.R. 3684: Infrastructure Investment and Jobs Act  \
# 1  2952375                   H.R. 5376: Build Back Better Act
#
#                          name  supporter_count  opposer_count
# 0                     Unknown               13              6
# 1  Rep. John Yarmuth (D-KY-3)                6             13

# %%
bills_analyser.parse_column_names_to_expected_output()
bills_analyser.order_columns_to_expected_output()

# %%
bills_analyser.write_csv()
